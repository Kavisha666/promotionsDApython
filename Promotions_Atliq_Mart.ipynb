# %% [markdown]
# # Import the fact_events.csv file

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\kirtik\\Desktop\\power-bi-course-resources-main\\C9 DATASET\\fact_events.csv")
df
# Out:
#      event_id store_id  campaign_id product_code  base_price    promo_type  \
# 0      7f650b  STCBE-2  CAMP_SAN_01          P11         190       50% OFF
# 1      a21f91  STBLR-8  CAMP_DIW_01          P03         156       25% OFF
# 2      78bc80  STVJD-0  CAMP_SAN_01          P07         300         BOGOF
# 3      a1503f  STCBE-1  CAMP_DIW_01          P15        3000  500 Cashback
# 4      1091cf  STBLR-6  CAMP_DIW_01          P05          55       25% OFF
# ...       ...      ...          ...          ...         ...           ...
# 1495   1e8961  STBLR-3  CAMP_SAN_01          P12          62       50% OFF
# 1496   f957f1  STMDU-1  CAMP_SAN_01          P10          50       25% OFF
# 1497   a9ae21  STCBE-0  CAMP_DIW_01          P12          62       50% OFF
# 1498   e5d28d  STVSK-0  CAMP_SAN_01          P13         350         BOGOF
# 1499   4d22d1  STBLR-9  CAMP_SAN_01          P12          62       50% OFF
#
#       quantity_sold(before_promo)  quantity_sold(after_promo)  Revenue Before  \
# 0                              34                          52            6460
# 1                             393                         322           61308
# 2                              22                          85            6600
# 3                             329                        1000          987000
# 4                             108                          93            5940
# ...                           ...                         ...             ...
# 1495                           61                          84            3782
# 1496                           22                          18            1100
# 1497                           80                         119            4960
# 1498                           73                         282           25550
# 1499                           52                          73            3224
#
#       Revenue After          IR   IR%  ISU  ISU%
# 0           4940.00    -1520.00  -24%   18   53%
# 1          37674.00   -23634.00  -39%  -71  -18%
# 2          25500.00    18900.00  286%  148  673%
# 3        2500000.00  1513000.00  153%  671  204%
# 4           3836.25    -2103.75  -35%  -15  -14%
# ...             ...         ...   ...  ...   ...
# 1495        2604.00    -1178.00  -31%   23   38%
# 1496         675.00     -425.00  -39%   -4  -18%
# 1497        3689.00    -1271.00  -26%   39   49%
# 1498       98700.00    73150.00  286%  491  673%
# 1499        2263.00     -961.00  -30%   21   40%
#
# [1500 rows x 14 columns]

# %%
##Display first n rows and last n rows.

# %%
df.head()
# Out:
#   event_id store_id  campaign_id product_code  base_price    promo_type  \
# 0   7f650b  STCBE-2  CAMP_SAN_01          P11         190       50% OFF
# 1   a21f91  STBLR-8  CAMP_DIW_01          P03         156       25% OFF
# 2   78bc80  STVJD-0  CAMP_SAN_01          P07         300         BOGOF
# 3   a1503f  STCBE-1  CAMP_DIW_01          P15        3000  500 Cashback
# 4   1091cf  STBLR-6  CAMP_DIW_01          P05          55       25% OFF
#
#    quantity_sold(before_promo)  quantity_sold(after_promo)  Revenue Before  \
# 0                           34                          52            6460
# 1                          393                         322           61308
# 2                           22                          85            6600
# 3                          329                        1000          987000
# 4                          108                          93            5940
#
#    Revenue After          IR   IR%  ISU  ISU%
# 0        4940.00    -1520.00  -24%   18   53%
# 1       37674.00   -23634.00  -39%  -71  -18%
# 2       25500.00    18900.00  286%  148  673%
# 3     2500000.00  1513000.00  153%  671  204%
# 4        3836.25    -2103.75  -35%  -15  -14%

# %%
df.tail()
# Out:
#      event_id store_id  campaign_id product_code  base_price promo_type  \
# 1495   1e8961  STBLR-3  CAMP_SAN_01          P12          62    50% OFF
# 1496   f957f1  STMDU-1  CAMP_SAN_01          P10          50    25% OFF
# 1497   a9ae21  STCBE-0  CAMP_DIW_01          P12          62    50% OFF
# 1498   e5d28d  STVSK-0  CAMP_SAN_01          P13         350      BOGOF
# 1499   4d22d1  STBLR-9  CAMP_SAN_01          P12          62    50% OFF
#
#       quantity_sold(before_promo)  quantity_sold(after_promo)  Revenue Before  \
# 1495                           61                          84            3782
# 1496                           22                          18            1100
# 1497                           80                         119            4960
# 1498                           73                         282           25550
# 1499                           52                          73            3224
#
#       Revenue After       IR   IR%  ISU  ISU%
# 1495         2604.0  -1178.0  -31%   23   38%
# 1496          675.0   -425.0  -39%   -4  -18%
# 1497         3689.0  -1271.0  -26%   39   49%
# 1498        98700.0  73150.0  286%  491  673%
# 1499         2263.0   -961.0  -30%   21   40%

# %%
##display the overall information of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   event_id                     1500 non-null   object
#  1   store_id                     1500 non-null   object
#  2   campaign_id                  1500 non-null   object
#  3   product_code                 1500 non-null   object
#  4   base_price                   1500 non-null   int64
#  5   promo_type                   1500 non-null   object
#  6   quantity_sold(before_promo)  1500 non-null   int64
#  7   quantity_sold(after_promo)   1500 non-null   int64
#  8   Revenue Before               1500 non-null   int64
#  9   Revenue After                1500 non-null   float64
#  10  IR                           1500 non-null   float64
#  11  IR%                          1500 non-null   object
#  12  ISU                          1500 non-null   int64
#  13  ISU%                         1500 non-null   object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 164.2+ KB

# %%
df.dtypes                            ##Display datatypes of a column in a table
# Out:
# event_id                        object
# store_id                        object
# campaign_id                     object
# product_code                    object
# base_price                       int64
# promo_type                      object
# quantity_sold(before_promo)      int64
# quantity_sold(after_promo)       int64
# Revenue Before                   int64
# Revenue After                  float64
# IR                             float64
# IR%                             object
# ISU                              int64
# ISU%                            object
# dtype: object

# %%
df.index                           ##Display the index of  a table
# Out:
# RangeIndex(start=0, stop=1500, step=1)

# %%
df.values                          ##Display only values in a table
# Out:
# array([['7f650b', 'STCBE-2', 'CAMP_SAN_01', ..., '-24%', 18, '53%'],
#        ['a21f91', 'STBLR-8', 'CAMP_DIW_01', ..., '-39%', -71, '-18%'],
#        ['78bc80', 'STVJD-0', 'CAMP_SAN_01', ..., '286%', 148, '673%'],
#        ...,
#        ['a9ae21', 'STCBE-0', 'CAMP_DIW_01', ..., '-26%', 39, '49%'],
#        ['e5d28d', 'STVSK-0', 'CAMP_SAN_01', ..., '286%', 491, '673%'],
#        ['4d22d1', 'STBLR-9', 'CAMP_SAN_01', ..., '-30%', 21, '40%']],
#       dtype=object)

# %%
df.axes                            ##Display index  & columns in a table
# Out:
# [RangeIndex(start=0, stop=1500, step=1),
#  Index(['event_id', 'store_id', 'campaign_id', 'product_code', 'base_price',
#         'promo_type', 'quantity_sold(before_promo)',
#         'quantity_sold(after_promo)', 'Revenue Before', 'Revenue After', 'IR',
#         'IR%', 'ISU', 'ISU%'],
#        dtype='object')]

# %%
df.shape                  ##Display the no.of rows & columns ina table
# Out:
# (1500, 14)

# %% [markdown]
# # import  dim_Products.csv

# %%
import pandas as pd

# %%
product=pd.read_csv("C:\\Users\\kirtik\\Desktop\\power-bi-course-resources-main\\C9 DATASET\\dim_products.csv")
product
# Out:
#    product_code                               product_name           category
# 0           P01                     Atliq_Masoor_Dal (1KG)  Grocery & Staples
# 1           P02               Atliq_Sonamasuri_Rice (10KG)  Grocery & Staples
# 2           P03                    Atliq_Suflower_Oil (1L)  Grocery & Staples
# 3           P04               Atliq_Farm_Chakki_Atta (1KG)  Grocery & Staples
# 4           P05            Atliq_Scrub_Sponge_For_Dishwash          Home Care
# 5           P06            Atliq_Fusion_Container_Set_of_3          Home Care
# 6           P09  Atliq_Body_Milk_Nourishing_Lotion (120ML)      Personal Care
# 7           P10    Atliq_Cream_Beauty_Bathing_Soap (125GM)      Personal Care
# 8           P13                Atliq_High_Glo_15W_LED_Bulb    Home Appliances
# 9           P14             Atliq_waterproof_Immersion_Rod    Home Appliances
# 10          P11      Atliq_Doodh_Kesar_Body_Lotion (200ML)      Personal Care
# 11          P12        Atliq_Lime_Cool_Bathing_Bar (125GM)      Personal Care
# 12          P07                             Atliq_Curtains          Home Care
# 13          P08                  Atliq_Double_Bedsheet_set          Home Care
# 14          P15       Atliq_Home_Essential_8_Product_Combo             Combo1

# %% [markdown]
# # Display the dim_stores.csv file

# %%
stores=pd.read_csv("C:\\Users\\kirtik\\Desktop\\power-bi-course-resources-main\\C9 DATASET\\dim_stores.csv")
stores
# Out:
#    store_id           city
# 0   STTRV-0     Trivandrum
# 1   STMDU-3        Madurai
# 2   STHYD-6      Hyderabad
# 3   STVSK-1  Visakhapatnam
# 4   STCBE-3     Coimbatore
# 5   STBLR-8      Bengaluru
# 6   STBLR-2      Bengaluru
# 7   STCHE-7        Chennai
# 8   STCBE-0     Coimbatore
# 9   STVSK-0  Visakhapatnam
# 10  STCHE-5        Chennai
# 11  STHYD-5      Hyderabad
# 12  STMDU-1        Madurai
# 13  STVJD-0     Vijayawada
# 14  STMDU-2        Madurai
# 15  STMYS-3         Mysuru
# 16  STMLR-0      Mangalore
# 17  STVSK-4  Visakhapatnam
# 18  STCHE-3        Chennai
# 19  STCHE-6        Chennai
# 20  STBLR-6      Bengaluru
# 21  STCBE-2     Coimbatore
# 22  STMLR-1      Mangalore
# 23  STCHE-2        Chennai
# 24  STCHE-1        Chennai
# 25  STBLR-5      Bengaluru
# 26  STMYS-0         Mysuru
# 27  STMDU-0        Madurai
# 28  STBLR-9      Bengaluru
# 29  STVSK-2  Visakhapatnam
# 30  STTRV-1     Trivandrum
# 31  STBLR-3      Bengaluru
# 32  STHYD-0      Hyderabad
# 33  STBLR-4      Bengaluru
# 34  STHYD-2      Hyderabad
# 35  STBLR-7      Bengaluru
# 36  STVSK-3  Visakhapatnam
# 37  STCBE-1     Coimbatore
# 38  STHYD-1      Hyderabad
# 39  STMYS-2         Mysuru
# 40  STMLR-2      Mangalore
# 41  STBLR-0      Bengaluru
# 42  STHYD-4      Hyderabad
# 43  STCHE-0        Chennai
# 44  STBLR-1      Bengaluru
# 45  STVJD-1     Vijayawada
# 46  STHYD-3      Hyderabad
# 47  STCHE-4        Chennai
# 48  STCBE-4     Coimbatore
# 49  STMYS-1         Mysuru

# %% [markdown]
# # import the Dim_campaigns.csv

# %%
campaigns=pd.read_csv("C:\\Users\\kirtik\\Desktop\\power-bi-course-resources-main\\C9 DATASET\\dim_campaigns.csv")
campaigns
# Out:
#    campaign_id campaign_name  start_date    end_date
# 0  CAMP_DIW_01        Diwali  12-11-2023  18-11-2023
# 1  CAMP_SAN_01     Sankranti  10-01-2024  16-01-2024

# %%
df.columns            ##display  the columns ina table
# Out:
# Index(['event_id', 'store_id', 'campaign_id', 'product_code', 'base_price',
#        'promo_type', 'quantity_sold(before_promo)',
#        'quantity_sold(after_promo)', 'Revenue Before', 'Revenue After', 'IR',
#        'IR%', 'ISU', 'ISU%'],
#       dtype='object')

# %%
df.size
# Out:
# 21000

# %% [markdown]
# # kpi Indicators

# %%
df['pp']= dp = (
    np.where(
        df["promo_type"] == "50% OFF",
        df["base_price"] * 0.5,
        np.where(
            df["promo_type"] == "33% OFF",
            df["base_price"] * 0.33,   
            np.where(
                df["promo_type"] == "BOGOF",
                df["base_price"] * (1 - 0.5),                                  
                np.where(
                    df["promo_type"] == "25% OFF",
                    df["base_price"] * 0.25,                             
                    np.where(df["promo_type"] == "500 Cashback",
                        500,
                        df["base_price"]
                    )
                )
            )
        )
    )
)
dp
# Out:
# array([ 95.,  39., 150., ...,  31., 175.,  31.])

# %%
discounted_Prices=dp*df["quantity_sold(after_promo)"]
discounted_Prices
# Out:
# 0         4940.00
# 1        12558.00
# 2        12750.00
# 3       500000.00
# 4         1278.75
#           ...
# 1495      2604.00
# 1496       225.00
# 1497      3689.00
# 1498     49350.00
# 1499      2263.00
# Name: quantity_sold(after_promo), Length: 1500, dtype: float64

# %%
discounted_Prices.sum()
# Out:
# 99875616.41

# %%
df.loc[df["promo_type"] == "BOGOF", "quantity_sold(after_promo)"] = df["quantity_sold(after_promo)"] * 2

# %%
Units_soldADP= df["quantity_sold(after_promo)"].sum()
Units_soldADP
# Out:
# 650726

# %%
Units_soldBDP=df["quantity_sold(before_promo)"].sum()
Units_soldBDP
# Out:
# 209050

# %%
ISU=Units_soldADP - Units_soldBDP
ISU
# Out:
# 441676

# %%
revenue_BDP=df["quantity_sold(before_promo)"]*df["base_price"]
revenue_BDP
# Out:
# 0         6460
# 1        61308
# 2         6600
# 3       987000
# 4         5940
#          ...
# 1495      3782
# 1496      1100
# 1497      4960
# 1498     25550
# 1499      3224
# Length: 1500, dtype: int64

# %%
sum_Revenue_BDP=revenue_BDP.sum()
sum_Revenue_BDP
# Out:
# 140701188

# %%
revenue_ADP = (df["base_price"] * df["quantity_sold(after_promo)"])-discounted_Prices
revenue_ADP
# Out:
# 0          4940.00
# 1         37674.00
# 2         38250.00
# 3       2500000.00
# 4          3836.25
#            ...
# 1495       2604.00
# 1496        675.00
# 1497       3689.00
# 1498     148050.00
# 1499       2263.00
# Length: 1500, dtype: float64

# %%
sum_Revenue_ADP=revenue_ADP.sum()
sum_Revenue_ADP
# Out:
# 343228753.59000003

# %%
IR=sum_Revenue_ADP - sum_Revenue_BDP
IR
# Out:
# 202527565.59000003

# %%
merged_df = pd.merge(df,stores, on='store_id', how='left')
merged_df
# Out:
#      event_id store_id  campaign_id product_code  base_price    promo_type  \
# 0      7f650b  STCBE-2  CAMP_SAN_01          P11         190       50% OFF
# 1      a21f91  STBLR-8  CAMP_DIW_01          P03         156       25% OFF
# 2      78bc80  STVJD-0  CAMP_SAN_01          P07         300         BOGOF
# 3      a1503f  STCBE-1  CAMP_DIW_01          P15        3000  500 Cashback
# 4      1091cf  STBLR-6  CAMP_DIW_01          P05          55       25% OFF
# ...       ...      ...          ...          ...         ...           ...
# 1495   1e8961  STBLR-3  CAMP_SAN_01          P12          62       50% OFF
# 1496   f957f1  STMDU-1  CAMP_SAN_01          P10          50       25% OFF
# 1497   a9ae21  STCBE-0  CAMP_DIW_01          P12          62       50% OFF
# 1498   e5d28d  STVSK-0  CAMP_SAN_01          P13         350         BOGOF
# 1499   4d22d1  STBLR-9  CAMP_SAN_01          P12          62       50% OFF
#
#       quantity_sold(before_promo)  quantity_sold(after_promo)  Revenue Before  \
# 0                              34                          52            6460
# 1                             393                         322           61308
# 2                              22                         170            6600
# 3                             329                        1000          987000
# 4                             108                          93            5940
# ...                           ...                         ...             ...
# 1495                           61                          84            3782
# 1496                           22                          18            1100
# 1497                           80                         119            4960
# 1498                           73                         564           25550
# 1499                           52                          73            3224
#
#       Revenue After          IR   IR%  ISU  ISU%      pp  Revenue_BDP  \
# 0           4940.00    -1520.00  -24%   18   53%   95.00         6460
# 1          37674.00   -23634.00  -39%  -71  -18%   39.00        61308
# 2          25500.00    18900.00  286%  148  673%  150.00         6600
# 3        2500000.00  1513000.00  153%  671  204%  500.00       987000
# 4           3836.25    -2103.75  -35%  -15  -14%   13.75         5940
# ...             ...         ...   ...  ...   ...     ...          ...
# 1495        2604.00    -1178.00  -31%   23   38%   31.00         3782
# 1496         675.00     -425.00  -39%   -4  -18%   12.50         1100
# 1497        3689.00    -1271.00  -26%   39   49%   31.00         4960
# 1498       98700.00    73150.00  286%  491  673%  175.00        25550
# 1499        2263.00     -961.00  -30%   21   40%   31.00         3224
#
#       Revenue_ADP            city
# 0          4940.00     Coimbatore
# 1         37674.00      Bengaluru
# 2         38250.00     Vijayawada
# 3       2500000.00     Coimbatore
# 4          3836.25      Bengaluru
# ...            ...            ...
# 1495       2604.00      Bengaluru
# 1496        675.00        Madurai
# 1497       3689.00     Coimbatore
# 1498     148050.00  Visakhapatnam
# 1499       2263.00      Bengaluru
#
# [1500 rows x 18 columns]

# %%
merged_df1 = pd.merge(df,product, on='product_code', how='left')
merged_df1
# Out:
#      event_id store_id  campaign_id product_code  base_price    promo_type  \
# 0      7f650b  STCBE-2  CAMP_SAN_01          P11         190       50% OFF
# 1      a21f91  STBLR-8  CAMP_DIW_01          P03         156       25% OFF
# 2      78bc80  STVJD-0  CAMP_SAN_01          P07         300         BOGOF
# 3      a1503f  STCBE-1  CAMP_DIW_01          P15        3000  500 Cashback
# 4      1091cf  STBLR-6  CAMP_DIW_01          P05          55       25% OFF
# ...       ...      ...          ...          ...         ...           ...
# 1495   1e8961  STBLR-3  CAMP_SAN_01          P12          62       50% OFF
# 1496   f957f1  STMDU-1  CAMP_SAN_01          P10          50       25% OFF
# 1497   a9ae21  STCBE-0  CAMP_DIW_01          P12          62       50% OFF
# 1498   e5d28d  STVSK-0  CAMP_SAN_01          P13         350         BOGOF
# 1499   4d22d1  STBLR-9  CAMP_SAN_01          P12          62       50% OFF
#
#       quantity_sold(before_promo)  quantity_sold(after_promo)  Revenue Before  \
# 0                              34                          52            6460
# 1                             393                         322           61308
# 2                              22                         170            6600
# 3                             329                        1000          987000
# 4                             108                          93            5940
# ...                           ...                         ...             ...
# 1495                           61                          84            3782
# 1496                           22                          18            1100
# 1497                           80                         119            4960
# 1498                           73                         564           25550
# 1499                           52                          73            3224
#
#       Revenue After          IR   IR%  ISU  ISU%      pp  Revenue_BDP  \
# 0           4940.00    -1520.00  -24%   18   53%   95.00         6460
# 1          37674.00   -23634.00  -39%  -71  -18%   39.00        61308
# 2          25500.00    18900.00  286%  148  673%  150.00         6600
# 3        2500000.00  1513000.00  153%  671  204%  500.00       987000
# 4           3836.25    -2103.75  -35%  -15  -14%   13.75         5940
# ...             ...         ...   ...  ...   ...     ...          ...
# 1495        2604.00    -1178.00  -31%   23   38%   31.00         3782
# 1496         675.00     -425.00  -39%   -4  -18%   12.50         1100
# 1497        3689.00    -1271.00  -26%   39   49%   31.00         4960
# 1498       98700.00    73150.00  286%  491  673%  175.00        25550
# 1499        2263.00     -961.00  -30%   21   40%   31.00         3224
#
#       Revenue_ADP                              product_name           category
# 0          4940.00    Atliq_Doodh_Kesar_Body_Lotion (200ML)      Personal Care
# 1         37674.00                  Atliq_Suflower_Oil (1L)  Grocery & Staples
# 2         38250.00                           Atliq_Curtains          Home Care
# 3       2500000.00     Atliq_Home_Essential_8_Product_Combo             Combo1
# 4          3836.25          Atliq_Scrub_Sponge_For_Dishwash          Home Care
# ...            ...                                      ...                ...
# 1495       2604.00      Atliq_Lime_Cool_Bathing_Bar (125GM)      Personal Care
# 1496        675.00  Atliq_Cream_Beauty_Bathing_Soap (125GM)      Personal Care
# 1497       3689.00      Atliq_Lime_Cool_Bathing_Bar (125GM)      Personal Care
# 1498     148050.00              Atliq_High_Glo_15W_LED_Bulb    Home Appliances
# 1499       2263.00      Atliq_Lime_Cool_Bathing_Bar (125GM)      Personal Care
#
# [1500 rows x 19 columns]

# %%
merged_df2 = pd.merge(df,campaigns, on='campaign_id', how='left')
merged_df2
# Out:
#      event_id store_id  campaign_id product_code  base_price    promo_type  \
# 0      7f650b  STCBE-2  CAMP_SAN_01          P11         190       50% OFF
# 1      a21f91  STBLR-8  CAMP_DIW_01          P03         156       25% OFF
# 2      78bc80  STVJD-0  CAMP_SAN_01          P07         300         BOGOF
# 3      a1503f  STCBE-1  CAMP_DIW_01          P15        3000  500 Cashback
# 4      1091cf  STBLR-6  CAMP_DIW_01          P05          55       25% OFF
# ...       ...      ...          ...          ...         ...           ...
# 1495   1e8961  STBLR-3  CAMP_SAN_01          P12          62       50% OFF
# 1496   f957f1  STMDU-1  CAMP_SAN_01          P10          50       25% OFF
# 1497   a9ae21  STCBE-0  CAMP_DIW_01          P12          62       50% OFF
# 1498   e5d28d  STVSK-0  CAMP_SAN_01          P13         350         BOGOF
# 1499   4d22d1  STBLR-9  CAMP_SAN_01          P12          62       50% OFF
#
#       quantity_sold(before_promo)  quantity_sold(after_promo)  Revenue Before  \
# 0                              34                          52            6460
# 1                             393                         322           61308
# 2                              22                         170            6600
# 3                             329                        1000          987000
# 4                             108                          93            5940
# ...                           ...                         ...             ...
# 1495                           61                          84            3782
# 1496                           22                          18            1100
# 1497                           80                         119            4960
# 1498                           73                         564           25550
# 1499                           52                          73            3224
#
#       Revenue After          IR   IR%  ISU  ISU%      pp  Revenue_BDP  \
# 0           4940.00    -1520.00  -24%   18   53%   95.00         6460
# 1          37674.00   -23634.00  -39%  -71  -18%   39.00        61308
# 2          25500.00    18900.00  286%  148  673%  150.00         6600
# 3        2500000.00  1513000.00  153%  671  204%  500.00       987000
# 4           3836.25    -2103.75  -35%  -15  -14%   13.75         5940
# ...             ...         ...   ...  ...   ...     ...          ...
# 1495        2604.00    -1178.00  -31%   23   38%   31.00         3782
# 1496         675.00     -425.00  -39%   -4  -18%   12.50         1100
# 1497        3689.00    -1271.00  -26%   39   49%   31.00         4960
# 1498       98700.00    73150.00  286%  491  673%  175.00        25550
# 1499        2263.00     -961.00  -30%   21   40%   31.00         3224
#
#       Revenue_ADP  campaign_name  start_date    end_date
# 0          4940.00     Sankranti  10-01-2024  16-01-2024
# 1         37674.00        Diwali  12-11-2023  18-11-2023
# 2         38250.00     Sankranti  10-01-2024  16-01-2024
# 3       2500000.00        Diwali  12-11-2023  18-11-2023
# 4          3836.25        Diwali  12-11-2023  18-11-2023
# ...            ...           ...         ...         ...
# 1495       2604.00     Sankranti  10-01-2024  16-01-2024
# 1496        675.00     Sankranti  10-01-2024  16-01-2024
# 1497       3689.00        Diwali  12-11-2023  18-11-2023
# 1498     148050.00     Sankranti  10-01-2024  16-01-2024
# 1499       2263.00     Sankranti  10-01-2024  16-01-2024
#
# [1500 rows x 20 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame

# Check DataFrame structure
print(df.head())  # Ensure 'promo_type', 'pp', and 'IR' columns are present

# Group by 'promo_type' and sum 'pp' and 'IR' separately
grouped_df = df.groupby('promo_type')['pp'].sum()
print(grouped_df)  # Check if grouping operation is returning the expected result

# Plot the bar chart
ax = grouped_df.plot(kind="bar")

# Add data labels
for i in ax.patches:
    ax.text(i.get_x() + i.get_width()/2, i.get_height(), 
            str(round(i.get_height(), 2)), 
            ha='center', va='bottom')

# Set labels and title
plt.xlabel('Promo Type')
plt.ylabel('Sum')
plt.title('Sum of pp by Promo Type')

# Show the plot
plt.show()
# Out:
#   event_id store_id  campaign_id product_code  base_price    promo_type  \
# 0   7f650b  STCBE-2  CAMP_SAN_01          P11         190       50% OFF
# 1   a21f91  STBLR-8  CAMP_DIW_01          P03         156       25% OFF
# 2   78bc80  STVJD-0  CAMP_SAN_01          P07         300         BOGOF
# 3   a1503f  STCBE-1  CAMP_DIW_01          P15        3000  500 Cashback
# 4   1091cf  STBLR-6  CAMP_DIW_01          P05          55       25% OFF
#
#    quantity_sold(before_promo)  quantity_sold(after_promo)  Revenue Before  \
# 0                           34                          52            6460
# 1                          393                         322           61308
# 2                           22                         170            6600
# 3                          329                        1000          987000
# 4                          108                          93            5940
#
#    Revenue After          IR   IR%  ISU  ISU%      pp  Revenue_BDP  \
# 0        4940.00    -1520.00  -24%   18   53%   95.00         6460
# 1       37674.00   -23634.00  -39%  -71  -18%   39.00        61308
# 2       25500.00    18900.00  286%  148  673%  150.00         6600
# 3     2500000.00  1513000.00  153%  671  204%  500.00       987000
# 4        3836.25    -2103.75  -35%  -15  -14%   13.75         5940
#
#    Revenue_ADP
# 0       4940.00
# 1      37674.00
# 2      38250.00
# 3    2500000.00
# 4       3836.25
# promo_type
# 25% OFF          19075.0
# 33% OFF          34056.0
# 50% OFF          16975.0
# 500 Cashback     50000.0
# BOGOF           157250.0
# Name: pp, dtype: float64

# %%
import matplotlib.pyplot as plt

# Group by 'product_code' and sum 'IR'
grouped_df = df.groupby('product_code')[['ISU']].sum()

# Plot the line chart
grouped_df.plot(kind="line",marker='o')
print(grouped_df)

# Set labels and title
plt.xlabel('Product Code')
plt.ylabel('Sum of Isu')
plt.title('Sum of Isu by Product Code')

# Show the plot
plt.show()
# Out:
#                  ISU
# product_code
# P01            11301
# P02            15954
# P03           104354
# P04           118030
# P05             -777
# P06             -735
# P07            28042
# P08            25913
# P09              556
# P10             1317
# P11             1765
# P12             2562
# P13            51611
# P14            40902
# P15            40881

# %%
import matplotlib.pyplot as plt

# Group by 'product_code' and sum 'IR'
grouped_df = df.groupby('product_code')[['pp']].sum()

# Plot the line chart
grouped_df.plot(kind="barh")
print(grouped_df)

# Set labels and title
plt.xlabel('Product Code')
plt.ylabel('Sum of IR')
plt.title('Sum of IR by Product Code')

# Show the plot
plt.show()
# Out:
#                    pp
# product_code
# P01            5676.0
# P02           28380.0
# P03            6950.0
# P04           12875.0
# P05            1375.0
# P06           10375.0
# P07           15000.0
# P08           59500.0
# P09            3875.0
# P10            2250.0
# P11            9500.0
# P12            3100.0
# P13           17500.0
# P14           51000.0
# P15           50000.0
